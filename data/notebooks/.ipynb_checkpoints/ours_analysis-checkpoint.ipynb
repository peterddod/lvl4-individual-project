# %%
import pylab as plt
import pandas as pd
import numpy as np

# %%
results_df = pd.read_csv('../raw/results_ours.csv')
results_df.columns = results_df.columns.str.strip()

# %%
iter_results_df = pd.read_csv('../raw/results_iter.csv')
iter_proc_df = iter_results_df.drop(columns=['seed']).groupby(['dataset','epochs']).agg([np.mean, np.std])
# Out:
# /var/folders/mr/vnkbxhh151s11m2mmshdgq080000gn/T/ipykernel_49855/3161366602.py:2: FutureWarning: ['name'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   iter_proc_df = iter_results_df.drop(columns=['seed']).groupby(['dataset','epochs']).agg([np.mean, np.std])

# %%
iter_proc_df
# Out:
#                      acc           train_time           test_time
#                     mean       std       mean       std      mean  std
# dataset epochs
# 0       1       0.967700  0.006722  29.380402  1.197794       0.0  0.0
#         2       0.973130  0.003481  58.733336  0.331585       0.0  0.0
#         3       0.971900  0.010574  87.602561  0.491000       0.0  0.0
# 1       1       0.854630  0.015073  28.744677  0.449991       0.0  0.0
#         2       0.866560  0.012413  57.404374  0.902878       0.0  0.0
#         3       0.872490  0.010412  86.909468  1.197727       0.0  0.0
# 2       1       0.778823  0.110935  16.004974  0.497718       0.0  0.0
#         2       0.777420  0.126687  31.752107  0.538644       0.0  0.0
#         3       0.783901  0.093009  47.242791  0.350255       0.0  0.0

# %%
ours_proc_df = results_df.drop(columns=['seed']).groupby(['dataset', 'subnets', 'h_size']).agg([np.mean,np.std])
# Out:
# /var/folders/mr/vnkbxhh151s11m2mmshdgq080000gn/T/ipykernel_49855/1671848631.py:1: FutureWarning: ['name', 'test_time'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   ours_proc_df = results_df.drop(columns=['seed']).groupby(['dataset', 'subnets', 'h_size']).agg([np.mean,np.std])

# %%
ours_proc_df
# Out:
#                              acc           train_time
#                             mean       std       mean       std
# dataset subnets h_size
# 0       1       100     0.946460  0.003259   2.733088  0.263313
#                 300     0.966370  0.002111   3.264333  0.017851
#                 900     0.977830  0.002200   6.066648  0.024878
#         2       100     0.963470  0.001544   3.583551  0.333925
#                 300     0.975670  0.001338   4.673055  0.104826
#                 900     0.983240  0.001115  10.500517  0.007311
#         3       100     0.968730  0.002126   3.948822  0.014444
#                 300     0.979210  0.001416   6.452789  0.067884
#                 900     0.985700  0.000826  15.321214  0.078656
#         5       100     0.974550  0.001144   5.294877  0.008570
#                 300     0.981670  0.001700   9.517482  0.013207
#                 900     0.986970  0.000548  25.784857  0.062501
#         7       100     0.976430  0.001209   6.592112  0.053182
#                 300     0.984080  0.000722  12.791350  0.026587
#                 900     0.987890  0.000731  38.057852  0.097580
#         9       100     0.978550  0.001357   7.896887  0.010990
#                 300     0.984870  0.000817  16.249745  0.019271
#                 900     0.988290  0.000853  52.183614  0.360826
# 1       1       100     0.683660  0.023946   2.624508  0.020841
#                 300     0.746650  0.019532   3.256400  0.020916
#                 900     0.759230  0.011294   5.734868  0.021766
#         2       100     0.723900  0.020599   3.263870  0.023166
#                 300     0.767000  0.007817   4.590571  0.031204
#                 900     0.782260  0.021292  10.256615  0.377184
#         3       100     0.734940  0.016422   3.887811  0.019435
#                 300     0.771630  0.017762   6.038092  0.011918
#                 900     0.794990  0.014072  15.312087  0.019660
#         5       100     0.748060  0.010987   5.217139  0.034772
#                 300     0.753200  0.025879   9.006463  0.004721
#                 900     0.778240  0.024167  25.810130  0.054704
#         7       100     0.748720  0.016195   6.566597  0.079148
#                 300     0.761850  0.021546  12.182541  0.189539
#                 900     0.777290  0.014813  38.080531  0.064854
#         9       100     0.752470  0.017147   7.822692  0.016768
#                 300     0.781060  0.022722  15.428101  0.048396
#                 900     0.769510  0.023889  52.317397  0.712952
# 2       1       100     0.734988  0.014479   3.262710  0.097520
#                 300     0.809280  0.013209   4.012723  0.015091
#                 900     0.856877  0.012151   7.128779  0.300875
#         2       100     0.800053  0.011880   4.028040  0.136759
#                 300     0.854099  0.010761   5.634831  0.045061
#                 900     0.883255  0.006697  12.109241  0.145348
#         3       100     0.826564  0.012743   4.787385  0.053383
#                 300     0.874255  0.011147   7.376878  0.015853
#                 900     0.893852  0.008263  17.572807  0.151703
#         5       100     0.849786  0.013762   6.331384  0.057550
#                 300     0.878815  0.014339  11.069071  0.284260
#                 900     0.895239  0.006334  29.407865  0.110511
#         7       100     0.862811  0.010479   7.956720  0.116450
#                 300     0.889947  0.008578  14.780727  0.085875
#         9       100     0.870947  0.007116   9.502938  0.025191
#                 300     0.892708  0.003743  18.880813  0.319929

# %% [markdown]
# ## MNIST

# %%
neurons = [100,300,900]
subnets = [1,2,3,5,7,9]

# %%
iter_proc_df.loc[0].loc[1]
# Out:
# acc         mean     0.967700
#             std      0.006722
# train_time  mean    29.380402
#             std      1.197794
# test_time   mean     0.000000
#             std      0.000000
# Name: 1, dtype: float64

# %%
plt.figure(figsize=(10, 7))
plt.title('MNIST PAE-ELM w/ Iter Baseline - Accuracy vs Subnets')
plt.xlabel('Subnets')
plt.ylabel('Accuracy (%)')



for size in neurons:
    data = ours_proc_df.loc[0].loc[(slice(None), size), :]['acc']['mean'].values*100
    err = ours_proc_df.loc[0].loc[(slice(None), size), :]['acc']['std'].values*100
    plt.errorbar(subnets, data, yerr=err, fmt='o-', linewidth=1, markersize=3, alpha=0.8, capsize=5)

plt.axhline(iter_proc_df.loc[0].loc[1]['acc']['mean']*100, color='red', linestyle=(0,(4,3)), alpha=0.5)
plt.axhline(iter_proc_df.loc[0].loc[2]['acc']['mean']*100, color='red', linestyle=(0,(8,3)), alpha=0.5)

plt.grid(which='both', alpha=0.5)
plt.legend(['iter-epoch-1', 'iter-epoch-2']+neurons)

# %% [markdown]
# Results look very stable. Accuracies are fairly outstanding compared to the iterative networks. Divided parallel networks seem to have no benefit in terms of accuracies over training all neurons at once.

# %%
plt.figure(figsize=(10, 7))
plt.title('MNIST PAE-ELM w/ Iter Baseline - Training Time vs Subnets')
plt.xlabel('Subnets')
plt.ylabel('Training Time (s)')

for size in neurons:
    data = ours_proc_df.loc[0].loc[(slice(None), size), :]['train_time']['mean'].values
    err = ours_proc_df.loc[0].loc[(slice(None), size), :]['train_time']['std'].values
    plt.errorbar(subnets, data, yerr=err, fmt='o-', linewidth=1, markersize=3, alpha=0.8, capsize=5)

plt.axhline(iter_proc_df.loc[0].loc[1]['train_time']['mean'], color='red', linestyle=(0,(4,3)), alpha=0.5)
plt.axhline(iter_proc_df.loc[0].loc[2]['train_time']['mean'], color='red', linestyle=(0,(8,3)), alpha=0.5)

plt.yscale('log')
plt.grid(which='both', alpha=0.5)
plt.legend(['iter-epoch-1', 'iter-epoch-2']+neurons)

# %% [markdown]
# Training times are also fairly outstanding. Discovery of PLPool2d in pytorch helps shave off a lot of time. Again, no benefit in divided networks in terms of training times, but this could be changed if the classifiers inputs are trained in parallel rather than just having a parallel structure.

# %% [markdown]
# ## Fashion MNIST

# %%
plt.figure(figsize=(10, 7))
plt.title('FSHN-MNIST PAE-ELM w/ Iter Baseline - Accuracy vs Subnets')
plt.xlabel('Subnets')
plt.ylabel('Accuracy (%)')

for size in neurons:
    data = ours_proc_df.loc[1].loc[(slice(None), size), :]['acc']['mean'].values*100
    err = ours_proc_df.loc[1].loc[(slice(None), size), :]['acc']['std'].values*100
    plt.errorbar(subnets, data, yerr=err, fmt='o-', linewidth=1, markersize=3, alpha=0.8, capsize=5)

plt.axhline(iter_proc_df.loc[1].loc[2]['acc']['mean']*100, color='red', linestyle=(0,(4,3)), alpha=0.5)
plt.axhline(iter_proc_df.loc[1].loc[3]['acc']['mean']*100, color='red', linestyle=(0,(8,3)), alpha=0.5)

plt.grid(which='both', alpha=0.5)
plt.legend(['iter-epoch-2', 'iter-epoch-3']+neurons)

# %% [markdown]
# On the contrary, these results are quite unstable. Some remarks:
# - Growing number of subnets doesn't seem to be an effective strategy in this dataset
# - The growth between 300 h_size and 900 h_size is not significant
# - Actual iterative results are needed for comparison to see if model is unsuitable for dataset
#
# Possible reasons for instablity:
# - Reduced number of training samples
# - Augmentation of input samples
# - Bad model for dataset
#
# Next steps:
# - Compare results to iterative results
# - Determine reasons for bad stability + performance
# - Try new models and rerun tests

# %%
plt.figure(figsize=(10, 7))
plt.title('FSHN-MNIST PAE-ELM w/ Iter Baseline - Training Time vs Subnets')
plt.xlabel('Subnets')
plt.ylabel('Training Time (s)')

for size in neurons:
    data = ours_proc_df.loc[1].loc[(slice(None), size), :]['train_time']['mean'].values
    err = ours_proc_df.loc[1].loc[(slice(None), size), :]['train_time']['std'].values
    plt.errorbar(subnets, data, yerr=err, fmt='o-', linewidth=1, markersize=3, alpha=0.8, capsize=5)

plt.axhline(iter_proc_df.loc[1].loc[2]['train_time']['mean'], color='red', linestyle=(0,(4,3)), alpha=0.5)
plt.axhline(iter_proc_df.loc[1].loc[3]['train_time']['mean'], color='red', linestyle=(0,(8,3)), alpha=0.5)

plt.yscale('log')
plt.grid(which='both', alpha=0.5)
plt.legend(['iter-epoch-2', 'iter-epoch-3']+neurons)

# %% [markdown]
# ## NORB

# %%
plt.figure(figsize=(10, 7))
plt.title('NORB PAE-ELM w/ Iter Baseline - Accuracy vs Subnets')
plt.xlabel('Subnets')
plt.ylabel('Accuracy (%)')

for size in neurons:
    data = ours_proc_df.loc[2].loc[(slice(None), size), :]['acc']['mean'].values*100
    err = ours_proc_df.loc[2].loc[(slice(None), size), :]['acc']['std'].values*100
    plt.errorbar(subnets[:len(data)], data, yerr=err, fmt='o-', linewidth=1, markersize=3, alpha=0.8, capsize=5)

plt.axhline(iter_proc_df.loc[2].loc[2]['acc']['mean']*100, color='red', linestyle=(0,(4,3)), alpha=0.5)
plt.axhline(iter_proc_df.loc[2].loc[3]['acc']['mean']*100, color='red', linestyle=(0,(8,3)), alpha=0.5)

plt.grid(which='both', alpha=0.5)
plt.legend(['iter-epoch-2', 'iter-epoch-3']+neurons)

# %% [markdown]
# Results look generally good for this dataset, although it would be good to get >90% accuracy. Some remarks:
# - Execution stopped for 900 h_size with >5 subnets due to too memory issues
# - For this dataset, parallel networks seemed to outperform non-parallel networks with the same complexity

# %%
plt.figure(figsize=(10, 7))
plt.title('NORB PAE-ELM w/ Iter Baseline - Training Time vs Subnets')
plt.xlabel('Subnets')
plt.ylabel('Training Time (s)')

for size in neurons:
    data = ours_proc_df.loc[2].loc[(slice(None), size), :]['train_time']['mean'].values
    err = ours_proc_df.loc[2].loc[(slice(None), size), :]['train_time']['std'].values
    plt.errorbar(subnets[:len(data)], data, yerr=err, fmt='o-', linewidth=1, markersize=3, alpha=0.8, capsize=5)

plt.axhline(iter_proc_df.loc[2].loc[2]['train_time']['mean'], color='red', linestyle=(0,(4,3)), alpha=0.5)
plt.axhline(iter_proc_df.loc[2].loc[3]['train_time']['mean'], color='red', linestyle=(0,(8,3)), alpha=0.5)

plt.yscale('log')
plt.grid(which='both', alpha=0.5)
plt.legend(['iter-epoch-2', 'iter-epoch-3']+neurons)
